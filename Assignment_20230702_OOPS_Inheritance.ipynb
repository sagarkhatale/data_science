# %%
"""
1. Explain what inheritance is in object-oriented programming and why it is used.

Answer : Inheritane is the concept in OOPS. One class can inherit the attributes and methods of 
other class. The class whoes properties are inherited is called base/parent class. And the class
that inherits the properties from parent class is called child class.

We use inheritance -
a) reuse code
b) to avoid data duplicity and data redundancy

"""

# %%
"""
2. Discuss the concept of single inheritance and multiple inheritance, highlighting their
differences and advantages.

Answer : 
Single inheritane - one derived class from one base class
Multiple inheritane - one derived class from many base class

As name suggest, main difference is number of parent class.

Advantages -
Modular code base - breaking down code into small chunks, makes it easy to understand.
Code reusability - child class copies attributes and methods of parent class and use.
Low maintenance - change the base class and it'll flow to derived class.

"""

# %%
"""
3. Explain the terms "base class" and "derived class" in the context of inheritance.

Answer : A class whose members are inherited is called base class. And the class that inherits those
members is called derived class.

"""

# %%
"""
4. What is the significance of the "protected" access modifier in inheritance? How does it differ from
"private" and "public" modifiers?

Answer : 
protected modifiers - these are only accessible to class derived from parent class. Data members of class
are declared protected by prefixing single underscore (_) to data member

private modifiers - these are accessible within the class only. Data members of class are declared protected
by prefixing double underscore (__) to data member

public modifiers - these are easily accessible from any part of the program. By default attributes and
methods are public

"""

# %%
"""
5. What is the purpose of the "super" keyword in inheritance? Provide an example.

Answer : super is builtin proxy object that allows to access methods of the base class

"""

class Person:
    def __init__(self, firstname, lastname):
        self.firstname = firstname
        self.lastname = lastname
        
    def fullname(self):
        print(f"Name : {self.firstname} {self.lastname}")
    
class Student(person):
    def __init__(self, firstname, lastname, grade):
        self.grade = grade
        super().__init__(firstname, lastname) # calling base constructor
        
    def display_details(self):
        super().fullname() # calling base class method
        print(f"Grade : {self.grade}")
        
std = Student('Sagar', 'Khatale', '10')
std.display_details()
# Out:
# Name : Sagar Khatale
# Grade : 10

# %%
"""
6. Create a base class called "Vehicle" with attributes like "make", "model", and "year".
Then, create a derived class called "Car" that inherits from "Vehicle" and adds an
attribute called "fuel_type". Implement appropriate methods in both classes.

Answer : 

"""

class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        
    def disp_vehicle(self):
        print("Vehicle details -")
        print(f"Make : {self.make}\nModel : {self.model}\nYear : {self.year}")
        
class Car(Vehicle):
    def __init__(self, make, model, year, fuel_type):
        super().__init__(make, model, year)
        self.fuel_type = fuel_type
        
    def disp_car(self):
        super().disp_vehicle()
        print(f"Fuel Type : {self.fuel_type}")
        
xuv700 = Car("Mahindra", "XUV700", 2022, "Hybrid")
xuv700.disp_car()
# Out:
# Vehicle details -
# Make : Mahindra
# Model : XUV700
# Year : 2022
# Fuel Type : Hybrid

# %%
"""
7. Create a base class called "Employee" with attributes like "name" and "salary."
Derive two classes, "Manager" and "Developer," from "Employee." Add an additional
attribute called "department" for the "Manager" class and "programming_language"
for the "Developer" class.

Answer : 

"""

class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
        
    def disp_emp(self):
        print(f"Emp name : {self.name}\nEmp salary : {self.salary}")
        
class Manager(Employee):
    def __init__(self, name, salary, dept):
        super().__init__(name, salary)
        self.dept = dept
        
    def disp_mngr(self):
        super().disp_emp()
        print(f"Dept : {self.dept}")
        
class Developer(Employee):
    def __init__(self, name, salary, prg_lang):
        super().__init__(name, salary)
        self.prg_lang = prg_lang
        
    def disp_dev(self):
        super().disp_emp()
        print(f"Programming Language : {self.prg_lang}")
        
e_1001 = Employee("Sagar", 18000)
e_1001.disp_emp()

print()
m_1001 = Manager("Dinesh", 49000, "Delivery")
m_1001.disp_mngr()

print()
d_1001 = Developer("Avinand", 35000, "Pro*C")
d_1001.disp_dev()
# Out:
# Emp name : Sagar
# Emp salary : 18000
#
# Emp name : Dinesh
# Emp salary : 49000
# Dept : Delivery
#
# Emp name : Avinand
# Emp salary : 35000
# Programming Language : Pro*C

# %%
"""
8. Design a base class called "Shape" with attributes like "colour" and "border_width."
Create derived classes, "Rectangle" and "Circle," that inherit from "Shape" and add
specific attributes like "length" and "width" for the "Rectangle" class and "radius" for
the "Circle" class.

Answer : 

"""

import math

class Shape:
    def __init__(self, colour, border_width):
        self.colour = colour
        self.border_width = border_width
        
    def disp_shape(self):
        print(f"Color : {self.colour}\nBorder Width : {self.border_width}")
        
class Rectangle(Shape):
    def __init__(self, colour, border_width, length, width):
        super().__init__(colour, border_width)
        self.length = length
        self.width = width
        
    def calc_area(self):
        super().disp_shape()
        print(f"Rectangle length : {self.length} width : {self.width}")
        print(f"Rectangle area : {self.length * self.width}")

class Circle(Shape):
    def __init__(self, colour, border_width, radius):
        super().__init__(colour, border_width)
        self.radius = radius
        
    def calc_area(self):
        super().disp_shape()
        print(f"Circle radius : {self.radius}")
        print(f"Circle area : {math.pi * self.radius**2:.2f}")

rect = Rectangle("Red", 1, 5, 4)
rect.calc_area()

print()
circle = Circle("Orange", 2, 10)
circle.calc_area()
# Out:
# Color : Red
# Border Width : 1
# Rectangle length : 5 width : 4
# Rectangle area : 20
#
# Color : Orange
# Border Width : 2
# Circle radius : 10
# Circle area : 314.16

# %%
"""
9. Create a base class called "Device" with attributes like "brand" and "model." Derive
two classes, "Phone" and "Tablet," from "Device." Add specific attributes like
"screen_size" for the "Phone" class and "battery_capacity" for the "Tablet" class.

Answer : 

"""

class Device:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model
        
    def disp_info(self):
        print(f"Brand : {self.brand}\nModel : {self.model}")
        
class Phone(Device):
    def __init__(self, brand, model, screen_size):
        super().__init__(brand, model)
        self.screen_size = screen_size
        
    def disp_phone(self):
        super().disp_info()
        print(f"Screen size : {self.screen_size}\"")
        
class Tablet(Device):
    def __init__(self, brand, model, mAh):
        super().__init__(brand, model)
        self.mAh = mAh
        
    def disp_tab(self):
        super().disp_info()
        print(f"Battery capacity : {self.mAh} mAh")

m2pro = Phone("Poco", "M2 Pro", "6.2")
m2pro.disp_phone()

print()
air = Tablet("Apple", "MacAir", 10000)
air.disp_tab()
# Out:
# Brand : Poco
# Model : M2 Pro
# Screen size : 6.2"
#
# Brand : Apple
# Model : MacAir
# Battery capacity : 10000 mAh

# %%
"""
10. Create a base class called "BankAccount" with attributes like "account_number" and
"balance." Derive two classes, "SavingsAccount" and "CheckingAccount," from
"BankAccount." Add specific methods like "calculate_interest" for the
"SavingsAccount" class and "deduct_fees" for the "CheckingAccount" class.

Answer : 

"""

class BankAccount:
    def __init__(self, acc_no, bal):
        self.acc_no = acc_no
        self.bal = bal
        
    def disp_acc_info(self):
        print(f"Account No : {self.acc_no}\nBalance : {self.bal}")
        
class SavingsAccount(BankAccount):
    int_rate = 2.4
    
    def __init__(self, acc_no, bal):
        super().__init__(acc_no, bal)
        
    def calc_int(self, int_rate = 0):
        super().disp_acc_info()
        
        if int_rate == 0:
            int_rate = self.int_rate
            
        int_on_bal = self.bal * int_rate / 100
        print(f"Interest on balance (ROI : {int_rate}%) : {int_on_bal}")
        self.bal += int_on_bal
        print(f"Total Balance : {self.bal}")

sa_01 = SavingsAccount(100231, 14000)
sa_01.calc_int()

print()
sa_02 = SavingsAccount(100232, 14000)
sa_02.calc_int(6)

class CheckingAccount(BankAccount):
    charge = 2
    
    def deduct_fees(self, fees = 0):
        super().disp_acc_info()
        
        if fees == 0:
            fees = self.charge
            
        chg_on_txn = self.bal * fees / 100
        print(f"Charges (fees : {fees}%) : {chg_on_txn}")
        self.bal -= chg_on_txn
        print(f"Total Balance : {self.bal}")

print()
ca_01 = CheckingAccount(100233, 24000)
ca_01.deduct_fees()

print()
ca_02 = CheckingAccount(100234, 24000)
ca_02.deduct_fees(1)
# Out:
# Account No : 100231
# Balance : 14000
# Interest on balance (ROI : 2.4%) : 336.0
# Total Balance : 14336.0
#
# Account No : 100232
# Balance : 14000
# Interest on balance (ROI : 6%) : 840.0
# Total Balance : 14840.0
#
# Account No : 100233
# Balance : 24000
# Charges (fees : 2%) : 480.0
# Total Balance : 23520.0
#
# Account No : 100234
# Balance : 24000
# Charges (fees : 1%) : 240.0
# Total Balance : 23760.0
